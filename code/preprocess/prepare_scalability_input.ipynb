# %%
import numpy as np
import pandas as pd
import os
import anndata as ad
from cellgrn.utils import load_scenic2, load_linger_all,load_figr, load_linger_ctx,generate_candidate_groups
# Out:
# /home/shaliu_fu/miniconda3/envs/sparsegrn/lib/python3.12/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]

# %%
outdir = "/home/shaliu_fu/multireg/cellGRN/data/bmmc/"
os.system(f"mkdir -p {outdir}")

gene_peak_res, tf_gene_res, tf_peak_res = load_scenic2('/home/shaliu_fu/multireg/benchmark/output/scalability/c50k/', 'scenic2_output')



scenic_res = generate_candidate_groups([tf_gene_res,gene_peak_res,tf_peak_res])
out_genes = pd.DataFrame(list(set(tf_gene_res['Gene']) | set(tf_gene_res['TF']) | set(gene_peak_res['Gene']) | set(tf_peak_res['TF']) ))
out_peaks = pd.DataFrame(list(set(gene_peak_res['Peak']) | set(tf_peak_res['Peak']) ))


scenic_res.to_csv(f"{outdir}/scenic2_grn.csv",header=True,index=False)
out_genes.to_csv(f"{outdir}/scenic2_gene.txt",header=False,index=False)
out_peaks.to_csv(f"{outdir}/scenic2_peak.txt",header=False,index=False)
# Out:
# /home/shaliu_fu/miniconda3/envs/sparsegrn/lib/python3.12/site-packages/cellgrn/utils.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scenic2_grn_out.drop_duplicates(inplace=True)
# /home/shaliu_fu/miniconda3/envs/sparsegrn/lib/python3.12/site-packages/cellgrn/utils.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scenic2_gene_peak_out.drop_duplicates(inplace=True)
# /home/shaliu_fu/miniconda3/envs/sparsegrn/lib/python3.12/site-packages/cellgrn/utils.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scenic2_tf_peak_out.drop_duplicates(inplace=True)

# %%
gene_peak_res, tf_gene_res, tf_peak_res = load_linger_ctx('/home/shaliu_fu/multireg/benchmark/output/scalability/c50k/', 'LINGER_output')
linger_res = generate_candidate_groups([tf_gene_res,gene_peak_res,tf_peak_res])

out_genes = pd.DataFrame(list(set(tf_gene_res['Gene']) | set(tf_gene_res['TF']) | set(gene_peak_res['Gene']) | set(tf_peak_res['TF']) ))
out_peaks = pd.DataFrame(list(set(gene_peak_res['Peak']) | set(tf_peak_res['Peak']) ))

linger_res.to_csv(f"{outdir}/linger_grn.csv",header=True,index=False)
out_genes.to_csv(f"{outdir}/linger_gene.txt",header=False,index=False)
out_peaks.to_csv(f"{outdir}/linger_peak.txt",header=False,index=False)
